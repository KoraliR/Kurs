# %% [markdown]
# Объединиение в один CSV

# %%
# import pandas as pd
# import glob
# import os
#
# path = r"D:\Photo"
# all_files = glob.glob(os.path.join(path, "*.csv"))
# main_df = None
# for file in all_files:
#     df = pd.read_table(file, sep=";")
#     if main_df is None:
#         main_df = df
#     else:
#         main_df = pd.concat([main_df, df], ignore_index=True)
# main_df.to_csv("true_output.csv", index=False, encoding='utf-8-sig')
# print(main_df)

# %%
import pandas as pd
import glob
import os

df = pd.read_table(r"final.csv", sep=";")
df = df.drop_duplicates()

# %% [markdown]
# Посмотрим характеристики

# %%
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 55152 entries, 0 to 61677
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   accommodation_type    55152 non-null  str
#  1   author                54079 non-null  str
#  2   author_type           54079 non-null  str
#  3   deal_type             55152 non-null  str
#  4   description           55152 non-null  str
#  5   district              41736 non-null  str
#  6   finish_type           55152 non-null  str
#  7   floor                 55152 non-null  int64
#  8   floors_count          55152 non-null  int64
#  9   heating_type          55152 non-null  int64
#  10  house_material_type   55152 non-null  str
#  11  house_number          48252 non-null  str
#  12  kitchen_meters        55152 non-null  str
#  13  living_meters         55152 non-null  str
#  14  location              55152 non-null  str
#  15  metro_distance        55152 non-null  int64
#  16  nearest_metro         55118 non-null  str
#  17  object_type           55152 non-null  int64
#  18  phone                 55151 non-null  float64
#  19  price                 55152 non-null  int64
#  20  residential_complex   30791 non-null  str
#  21  rooms_count           55152 non-null  int64
#  22  street                47459 non-null  str
#  23  total_meters          55152 non-null  float64
#  24  transport_score       55152 non-null  float64
#  25  underground           50581 non-null  str
#  26  url                   55152 non-null  str
#  27  year_of_construction  55152 non-null  str
# dtypes: float64(3), int64(7), str(18)
# memory usage: 12.2 MB
#   accommodation_type             author        author_type deal_type  \
# 0               flat       Центр Инвест  real_estate_agent      sale
# 1               flat  Apple Real Estate  real_estate_agent      sale
# 2               flat       ID 119690304          homeowner      sale
# 3               flat       Центр Инвест  real_estate_agent      sale
# 4               flat          Whitewill  real_estate_agent      sale
#
#                                          description        district  \
# 0  О ПРОЕКТЕ:\n\nWill Towers — жилой комплекс биз...         Раменки
# 1  Лот 1000259. Виктория Шевцова.\n\nРады предлож...         Раменки
# 2  УСЛУГИ ПРОСЬБА НЕ ПРЕДЛАГАТЬ !!! \nПродает соб...  Филевский парк
# 3  О ПРОЕКТЕ:\n\nWill Towers — жилой комплекс биз...         Раменки
# 4  Квартира с двумя спальнями в комплексе премиум...         Раменки
#
#    finish_type  floor  floors_count  heating_type  ...         phone  \
# 0  Без отделки     35            56            -1  ...  7.923071e+10
# 1           -1      9            19            -1  ...  7.915314e+10
# 2           -1      7             8            -1  ...  7.916816e+10
# 3  Без отделки     33            56            -1  ...  7.923071e+10
# 4     Чистовая     23            40            -1  ...  7.985722e+10
#
#       price residential_complex rooms_count                      street  \
# 0  28127104         Will Towers           2  проспект Генерала Дорохова
# 1  41500000     Золотые Ключи 2           2                    Минская
# 2  17850000                 NaN           2            Василисы Кожиной
# 3  38320818         Will Towers           2  проспект Генерала Дорохова
# 4  51000000             Нова ЖК           2                         NaN
#
#    total_meters transport_score  underground  \
# 0          51.3             5.2      Минская
# 1          67.0            -1.0      Минская
# 2          40.0            -1.0      Минская
# 3          73.4             5.2      Минская
# 4          54.0            -1.0      Минская
#
#                                                  url  year_of_construction
# 0  https://www.cian.ru/sale/flat/320392576/?mlSea...                  2024
# 1  https://www.cian.ru/sale/flat/326688167/?mlSea...                  2004
# 2  https://www.cian.ru/sale/flat/322956324/?mlSea...                  1960
# 3  https://www.cian.ru/sale/flat/320392568/?mlSea...                  2024
# 4  https://www.cian.ru/sale/flat/327116733/?mlSea...                  2027
#
# [5 rows x 28 columns]

# %% [markdown]
# Удалим ненужные столбцы: author, author_type, house_number, residental_complex, street,url

# %%
df.drop(columns=['author', 'author_type', 'house_number', 'residential_complex', 'street','url'], inplace=True)
df.head()
# Out:
#   accommodation_type deal_type  \
# 0               flat      sale
# 1               flat      sale
# 2               flat      sale
# 3               flat      sale
# 4               flat      sale
#
#                                          description        district  \
# 0  О ПРОЕКТЕ:\n\nWill Towers — жилой комплекс биз...         Раменки
# 1  Лот 1000259. Виктория Шевцова.\n\nРады предлож...         Раменки
# 2  УСЛУГИ ПРОСЬБА НЕ ПРЕДЛАГАТЬ !!! \nПродает соб...  Филевский парк
# 3  О ПРОЕКТЕ:\n\nWill Towers — жилой комплекс биз...         Раменки
# 4  Квартира с двумя спальнями в комплексе премиум...         Раменки
#
#    finish_type  floor  floors_count  heating_type house_material_type  \
# 0  Без отделки     35            56            -1          Монолитный
# 1           -1      9            19            -1                  -1
# 2           -1      7             8            -1                  -1
# 3  Без отделки     33            56            -1          Монолитный
# 4     Чистовая     23            40            -1                  -1
#
#   kitchen_meters  ... metro_distance           nearest_metro  object_type  \
# 0           6 м²  ...             19                 Минская           -1
# 1          18 м²  ...             16  Ломоносовский проспект           -1
# 2          15 м²  ...             11          Филёвский парк           -1
# 3         6,1 м²  ...             19                 Минская           -1
# 4             -1  ...             15                 Минская           -1
#
#           phone     price  rooms_count  total_meters  transport_score  \
# 0  7.923071e+10  28127104            2          51.3              5.2
# 1  7.915314e+10  41500000            2          67.0             -1.0
# 2  7.916816e+10  17850000            2          40.0             -1.0
# 3  7.923071e+10  38320818            2          73.4              5.2
# 4  7.985722e+10  51000000            2          54.0             -1.0
#
#    underground  year_of_construction
# 0      Минская                  2024
# 1      Минская                  2004
# 2      Минская                  1960
# 3      Минская                  2024
# 4      Минская                  2027
#
# [5 rows x 22 columns]

# %%
print(df['accommodation_type'].value_counts())
df['deal_type'].value_counts()
df['location'].value_counts()
# Out:
# accommodation_type
# flat    55152
# Name: count, dtype: int64
# location
# Москва    55152
# Name: count, dtype: int64

# %% [markdown]
# Удалим столбцы accommodation-type, location и deal_type т.к в них лишь одно уникальное значение. Также удалим столбец underground

# %%
df.drop(columns=["accommodation_type", "deal_type", "underground", "location", "description", "nearest_metro"], inplace=True)

# %% [markdown]
# Посмотрим, в скольких строках данных содержаться пропуски и сравним с общим размером записей

# %%
print(df.shape)
df.isna().sum(axis=0)
# Out:
# (55152, 16)
# district                13416
# finish_type                 0
# floor                       0
# floors_count                0
# heating_type                0
# house_material_type         0
# kitchen_meters              0
# living_meters               0
# metro_distance              0
# object_type                 0
# phone                       1
# price                       0
# rooms_count                 0
# total_meters                0
# transport_score             0
# year_of_construction        0
# dtype: int64

# %% [markdown]
# Удалим строки с пропусками данных в колонке district

# %%
df.dropna()
# Out:
#                district  finish_type  floor  floors_count  heating_type  \
# 0               Раменки  Без отделки     35            56            -1
# 1               Раменки           -1      9            19            -1
# 2        Филевский парк           -1      7             8            -1
# 3               Раменки  Без отделки     33            56            -1
# 4               Раменки     Чистовая     23            40            -1
# ...                 ...          ...    ...           ...           ...
# 61671   Бескудниковский           -1      2            16            -1
# 61672  Косино-Ухтомский           -1      3            12            -1
# 61674   Выхино-Жулебино           -1      3             9            -1
# 61675           Кунцево           -1      1            12            -1
# 61677         Кузьминки           -1      3            17            -1
#
#       house_material_type kitchen_meters living_meters  metro_distance  \
# 0              Монолитный           6 м²       33,3 м²              19
# 1                      -1          18 м²         20 м²              16
# 2                      -1          15 м²         20 м²              11
# 3              Монолитный         6,1 м²       44,8 м²              19
# 4                      -1             -1         49 м²              15
# ...                   ...            ...           ...             ...
# 61671                  -1           8 м²         46 м²              11
# 61672                  -1        30,8 м²       31,1 м²               5
# 61674                  -1           6 м²       44,3 м²              18
# 61675                  -1           7 м²       46,4 м²              11
# 61677                  -1          10 м²         45 м²              12
#
#        object_type         phone     price  rooms_count  total_meters  \
# 0               -1  7.923071e+10  28127104            2          51.3
# 1               -1  7.915314e+10  41500000            2          67.0
# 2               -1  7.916816e+10  17850000            2          40.0
# 3               -1  7.923071e+10  38320818            2          73.4
# 4               -1  7.985722e+10  51000000            2          54.0
# ...            ...           ...       ...          ...           ...
# 61671           -1  7.916591e+10  16900000            3          65.0
# 61672           -1  7.923072e+10  17000000            3          76.8
# 61674           -1  7.986264e+10  17000000            3          58.8
# 61675           -1  7.910474e+10  16900000            3          63.7
# 61677           -1  7.916194e+10  19500000            3          74.7
#
#        transport_score year_of_construction
# 0                  5.2                 2024
# 1                 -1.0                 2004
# 2                 -1.0                 1960
# 3                  5.2                 2024
# 4                 -1.0                 2027
# ...                ...                  ...
# 61671             -1.0                 1976
# 61672             -1.0                 2022
# 61674             -1.0                 1968
# 61675             -1.0                 1974
# 61677             -1.0                 1999
#
# [41735 rows x 16 columns]

# %% [markdown]
# Вместо районов будем использовать округа

# %%
import json
with open("county_district.json", 'r', encoding='utf-8') as file:
    districts = json.load(file)
new_districts = dict()
for i in districts:
    name = i['name']
    county_id = i['county_id']
    new_districts[name] = county_id
with open("county.json", 'r', encoding='utf-8') as file:
    countis = json.load(file)
new_countis = dict()
for i in countis:
    short_name = i['short']
    id_c = i['id']
    new_countis[id_c] = short_name
print(new_countis)
print(new_districts)

df['district'] = df['district'].replace(new_districts)
df.head()
# Out:
# {1: 'СЗАО', 2: 'САО', 3: 'СВАО', 4: 'ЗАО', 5: 'ЦАО', 6: 'ВАО', 7: 'ЮЗАО', 8: 'ЮАО', 9: 'ЮВАО', 10: 'ЗелАО', 11: 'НАО', 12: 'ТАО'}
# {'Куркино': 1, 'Митино': 1, 'Покровское-Стрешнево': 1, 'Северное Тушино': 1, 'Строгино': 1, 'Хорошево-Мневники': 1, 'Щукино': 1, 'Южное Тушино': 1, 'Северный (САО)': 2, 'Аэропорт': 2, 'Беговой': 2, 'Бескудниковский': 2, 'Войковский': 2, 'Восточное Дегунино': 2, 'Западное Дегунино': 2, 'Головинский': 2, 'Дмитровский': 2, 'Коптево': 2, 'Левобережный': 2, 'Молжаниновский': 2, 'Савеловский': 2, 'Сокол': 2, 'Тимирязевский': 2, 'Ховрино': 2, 'Хорошевский': 2, 'Алексеевский': 3, 'Алтуфьевский': 3, 'Бабушкинский': 3, 'Бибирево': 3, 'Бутырский': 3, 'Лианозово': 3, 'Лосиноостровский': 3, 'Марфино': 3, 'Марьина Роща': 3, 'Останкинский': 3, 'Отрадное': 3, 'Ростокино': 3, 'Свиблово': 3, 'Северное Медведково': 3, 'Южное Медведково': 3, 'Северный': 3, 'Ярославский': 3, 'Внуково': 4, 'Дорогомилово': 4, 'Крылатское': 4, 'Кунцево': 4, 'Можайский': 4, 'Ново-Переделкино': 4, 'Очаково-Матвеевское': 4, 'Проспект Вернадского': 4, 'Раменки': 4, 'Солнцево': 4, 'Тропарево-Никулино': 4, 'Филевский Парк': 4, 'Фили-Давыдково': 4, 'Арбат': 5, 'Басманный': 5, 'Замоскворечье': 5, 'Красносельский': 5, 'Мещанский': 5, 'Пресненский': 5, 'Таганский': 5, 'Тверской': 5, 'Хамовники': 5, 'Якиманка': 5, 'Богородское': 6, 'Вешняки': 6, 'Восточное Измайлово': 6, 'Северное Измайлово': 6, 'Восточный': 6, 'Гольяново': 6, 'Ивановское': 6, 'Измайлово': 6, 'Косино-Ухтомский': 6, 'Метрогородок': 6, 'Новогиреево': 6, 'Новокосино': 6, 'Перово': 6, 'Преображенское': 6, 'Соколиная Гора': 6, 'Сокольники': 6, 'Академический': 7, 'Гагаринский': 7, 'Зюзино': 7, 'Коньково': 7, 'Котловка': 7, 'Ломоносовский': 7, 'Обручевский': 7, 'Северное Бутово': 7, 'Южное Бутово': 7, 'Теплый Стан': 7, 'Черемушки': 7, 'Ясенево': 7, 'Бирюлево Восточное': 8, 'Бирюлево Западное': 8, 'Братеево': 8, 'Даниловский': 8, 'Донской': 8, 'Зябликово': 8, 'Москворечье-Сабурово': 8, 'Нагатино-Садовники': 8, 'Нагатинский Затон': 8, 'Нагорный': 8, 'Орехово-Борисово Северное': 8, 'Орехово-Борисово Южное': 8, 'Царицыно': 8, 'Чертаново Северное': 8, 'Чертаново Центральное': 8, 'Чертаново Южное': 8, 'Выхино-Жулебино': 9, 'Капотня': 9, 'Кузьминки': 9, 'Лефортово': 9, 'Люблино': 9, 'Марьино': 9, 'Некрасовка': 9, 'Нижегородский': 9, 'Печатники': 9, 'Рязанский': 9, 'Текстильщики': 9, 'Южнопортовый': 9, 'Крюково': 10, 'Матушкино': 10, 'Савёлки': 10, 'Силино': 10, 'Старое Крюково': 10, 'Внуковское': 11, 'Воскресенское': 11, 'Десёновское': 11, 'Кокошкино': 11, 'Марушкинское': 11, 'Московский': 11, 'Мосрентген': 11, 'Рязановское': 11, 'Сосенское': 11, 'Филимонковское': 11, 'Щербинка': 11, 'Вороновское': 12, 'Киевский': 12, 'Кленовское': 12, 'Краснопахорское': 12, 'Михайлово-Ярцевское': 12, 'Новофедоровское': 12, 'Первомайское': 12, 'Роговское': 12, 'Троицк': 12, 'Щаповское': 12}
#          district  finish_type  floor  floors_count  heating_type  \
# 0               4  Без отделки     35            56            -1
# 1               4           -1      9            19            -1
# 2  Филевский парк           -1      7             8            -1
# 3               4  Без отделки     33            56            -1
# 4               4     Чистовая     23            40            -1
#
#   house_material_type kitchen_meters living_meters  metro_distance  \
# 0          Монолитный           6 м²       33,3 м²              19
# 1                  -1          18 м²         20 м²              16
# 2                  -1          15 м²         20 м²              11
# 3          Монолитный         6,1 м²       44,8 м²              19
# 4                  -1             -1         49 м²              15
#
#    object_type         phone     price  rooms_count  total_meters  \
# 0           -1  7.923071e+10  28127104            2          51.3
# 1           -1  7.915314e+10  41500000            2          67.0
# 2           -1  7.916816e+10  17850000            2          40.0
# 3           -1  7.923071e+10  38320818            2          73.4
# 4           -1  7.985722e+10  51000000            2          54.0
#
#    transport_score year_of_construction
# 0              5.2                 2024
# 1             -1.0                 2004
# 2             -1.0                 1960
# 3              5.2                 2024
# 4             -1.0                 2027

# %% [markdown]
# Проверим корректность замены

# %%
df['district'].value_counts()
# Out:
# district
# 5                                                                                                                                                             10285
# 4                                                                                                                                                              5847
# 2                                                                                                                                                              4814
# 8                                                                                                                                                              4040
# 9                                                                                                                                                              2912
#                                                                                                                                                               ...
# в ЖК Riga Hills площадью 101.19кв.м.\nОтделка черновая. \n\nПолучение ключей от застройщика до июня 2026 года. \n\nRiga Hills - яркий проект бизнес-класса        1
# д. Сколково                                                                                                                                                       1
# Лучшая 3кв-ра в Алексеевском е3-комн. квартира                                                                                                                    1
# Лопатино пгт                                                                                                                                                      1
# с. Кленово                                                                                                                                                        1
# Name: count, Length: 222, dtype: int64

# %% [markdown]
# Исправим недостатки

# %%
countis = {
    "Марьина роща": 3,
    "Филевсий парк": 4,
    "Соколиная гора": 6,
    "Нагатинский затон":8,
    "Филевский парк": 4

}
df['district'] = df['district'].replace(countis)
df['district'].value_counts()
# Out:
# district
# 5                                                                                                                                                             10285
# 4                                                                                                                                                              6045
# 2                                                                                                                                                              4814
# 8                                                                                                                                                              4442
# 3                                                                                                                                                              3043
#                                                                                                                                                               ...
# в ЖК Riga Hills площадью 101.19кв.м.\nОтделка черновая. \n\nПолучение ключей от застройщика до июня 2026 года. \n\nRiga Hills - яркий проект бизнес-класса        1
# д. Сколково                                                                                                                                                       1
# Лучшая 3кв-ра в Алексеевском е3-комн. квартира                                                                                                                    1
# Лопатино пгт                                                                                                                                                      1
# с. Кленово                                                                                                                                                        1
# Name: count, Length: 218, dtype: int64

# %% [markdown]
# Удалим мусор

# %%
df['district'] = pd.to_numeric(df['district'], errors='coerce')
df = df.dropna(subset=['district'])
df['district'].value_counts()
# Out:
# district
# 5.0     10285
# 4.0      6045
# 2.0      4814
# 8.0      4442
# 3.0      3043
# 9.0      2912
# 6.0      2759
# 1.0      2319
# 7.0      2291
# 10.0      156
# 12.0        1
# Name: count, dtype: int64

# %% [markdown]
# Применим OneHotEncoder для столбца district

# %%
df = pd.get_dummies(df, columns=['district'])
df.head()
# Out:
#    finish_type  floor  floors_count  heating_type house_material_type  \
# 0  Без отделки     35            56            -1          Монолитный
# 1           -1      9            19            -1                  -1
# 2           -1      7             8            -1                  -1
# 3  Без отделки     33            56            -1          Монолитный
# 4     Чистовая     23            40            -1                  -1
#
#   kitchen_meters living_meters  metro_distance  object_type         phone  \
# 0           6 м²       33,3 м²              19           -1  7.923071e+10
# 1          18 м²         20 м²              16           -1  7.915314e+10
# 2          15 м²         20 м²              11           -1  7.916816e+10
# 3         6,1 м²       44,8 м²              19           -1  7.923071e+10
# 4             -1         49 м²              15           -1  7.985722e+10
#
#    ...  district_2.0  district_3.0  district_4.0  district_5.0 district_6.0  \
# 0  ...         False         False          True         False        False
# 1  ...         False         False          True         False        False
# 2  ...         False         False          True         False        False
# 3  ...         False         False          True         False        False
# 4  ...         False         False          True         False        False
#
#    district_7.0  district_8.0  district_9.0  district_10.0  district_12.0
# 0         False         False         False          False          False
# 1         False         False         False          False          False
# 2         False         False         False          False          False
# 3         False         False         False          False          False
# 4         False         False         False          False          False
#
# [5 rows x 26 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

y = df['price']
df.drop(columns=['price'], inplace=True)
X = df
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)



regressor = LinearRegression()
regressor.fit(X_train, y_train)




mine = [10, 18, 3, 60, False, False, False, False, False, False, True, False, False, False]


# or
mine = [mine]

a = regressor.predict(mine)
print(a)

y_pred = regressor.predict(X_test)


score_r2 = r2_score(y_test, y_pred)
mse_score = mean_squared_error(y_test, y_pred)

print(f"score_r2 = {score_r2}")
print(f"mse score = {mse_score}")
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
print(f"MAPE: {mape:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 13
#       8 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#      12 regressor = LinearRegression()
# ---> 13 regressor.fit(X_train, y_train)
#      18 mine = [10, 18, 3, 60, False, False, False, False, False, False, True, False, False, False]
#      21 # or
#
# File D:\Photo\.venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File D:\Photo\.venv\Lib\site-packages\sklearn\linear_model\_base.py:630, in LinearRegression.fit(self, X, y, sample_weight)
#     626 n_jobs_ = self.n_jobs
#     628 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 630 X, y = validate_data(
#     631     self,
#     632     X,
#     633     y,
#     634     accept_sparse=accept_sparse,
#     635     y_numeric=True,
#     636     multi_output=True,
#     637     force_writeable=True,
#     638 )
#     640 has_sw = sample_weight is not None
#     641 if has_sw:
#
# File D:\Photo\.venv\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2917         y = check_array(y, input_name="y", **check_y_params)
#    2918     else:
# -> 2919         X, y = check_X_y(X, y, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\Photo\.venv\Lib\site-packages\sklearn\utils\validation.py:1314, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1309         estimator_name = _check_estimator_name(estimator)
#    1310     raise ValueError(
#    1311         f"{estimator_name} requires y to be passed, but the target y is None"
#    1312     )
# -> 1314 X = check_array(
#    1315     X,
#    1316     accept_sparse=accept_sparse,
#    1317     accept_large_sparse=accept_large_sparse,
#    1318     dtype=dtype,
#    1319     order=order,
#    1320     copy=copy,
#    1321     force_writeable=force_writeable,
#    1322     ensure_all_finite=ensure_all_finite,
#    1323     ensure_2d=ensure_2d,
#    1324     allow_nd=allow_nd,
#    1325     ensure_min_samples=ensure_min_samples,
#    1326     ensure_min_features=ensure_min_features,
#    1327     estimator=estimator,
#    1328     input_name="X",
#    1329 )
#    1331 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1333 check_consistent_length(X, y)
#
# File D:\Photo\.venv\Lib\site-packages\sklearn\utils\validation.py:940, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     935 if pandas_requires_conversion:
#     936     # pandas dataframe requires conversion earlier to handle extension dtypes with
#     937     # nans
#     938     # Use the original dtype for conversion if dtype is None
#     939     new_dtype = dtype_orig if dtype is None else dtype
# --> 940     array = array.astype(new_dtype)
#     941     # Since we converted here, we do not need to convert again later
#     942     dtype = None
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File D:\Photo\.venv\Lib\site-packages\pandas\core\arrays\string_.py:940, in StringArray.astype(self, dtype, copy)
#     938 mask = self.isna()
#     939 arr[mask] = 0
# --> 940 values = arr.astype(dtype)
#     941 values[mask] = np.nan
#     942 return values
#
# ValueError: could not convert string to float: 'Без отделки, предчистовая'

# %% [markdown]
# knn

# %%
from sklearn.neighbors import KNeighborsRegressor

regressor = KNeighborsRegressor()
regressor.fit(X_train, y_train)


mine = [10, 18, 3, 60, False, False, False, False, False, False, True, False, False, False]


# or
mine = [mine]

a = regressor.predict(mine)
print(a)


y_pred = regressor.predict(X_test)


score_r2 = r2_score(y_test, y_pred)
mse_score = mean_squared_error(y_test, y_pred)

print(f"score_r2 = {score_r2}")
print(f"mse score = {mse_score}")
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
print(f"MAPE: {mape:.1f}%")
# Out:
# C:\Users\User\Desktop\Учеба\Project\LinearRegression\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# [27900000.]
# score_r2 = 0.9427211521530968
# mse score = 2174125233441645.5
# MAPE: 2.8%

# %% [markdown]
# tree

# %%
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_absolute_percentage_error




regressor = DecisionTreeRegressor(max_depth=5)
regressor.fit(X_train, y_train)


mine = [10, 18, 3, 60, False, False, False, False, False, False, True, False, False, False]


# or
mine = [mine]

a = regressor.predict(mine)
print(a)




y_pred = regressor.predict(X_test)


score_r2 = r2_score(y_test, y_pred)
mse_score = mean_squared_error(y_test, y_pred)

print(f"score_r2 = {score_r2}")
print(f"mse score = {mse_score}")
mape = mean_absolute_percentage_error(y_test, y_pred) * 100
print(f"MAPE: {mape:.1f}%")
# Out:
# [19042025.8637733]
# score_r2 = 0.745016162519027
# mse score = 9678385931729920.0
# MAPE: 39.9%
# C:\Users\User\Desktop\Учеба\Project\LinearRegression\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
